# %%
from random import random  

sample_list_1 = []
 
for i in range(80):
    sample_list_1.append(random())
print(sample_list_1)
# Out:
# [0.7235675066861962, 0.4520688792143841, 0.5288082864381142, 0.7632245341031687, 0.43109172379973604, 0.8957296595219961, 0.10304121672068967, 0.471678261351385, 0.47526165390596375, 0.8504013851262702, 0.31872358231863385, 0.6167341761094327, 0.6345681619147643, 0.24357206967582146, 0.10932382978732458, 0.8301799353905501, 0.44567810377570016, 0.48077146126142667, 0.9056407218698925, 0.024325494547958626, 0.6089164137864687, 0.7165658556894765, 0.32354059812282465, 0.8149943150173597, 0.5555874558471873, 0.6360466578490152, 0.43031407528222276, 0.9860895889340866, 0.6928329208882981, 0.055687489690714354, 0.9606629147570452, 0.12603972625848414, 0.8789272967373528, 0.29730695702936094, 0.09006541040829608, 0.4119305404831587, 0.9464137756120352, 0.3566765779224472, 0.289419647085455, 0.026334382861903705, 0.718882920968379, 0.7729921316635406, 0.19824253441156403, 0.4434616008186608, 0.5034338997101593, 0.25316006007152614, 0.05917837814358751, 0.030134570979092667, 0.14685699981790
# ...

# %%
len(sample_list_1)
# Out:
# 80

# %%
set1=set(sample_list_1)

# %%
print(len(set1))
# Out:
# 80

# %%
from random import random  

sample_list_2 = []
 
for i in range(80):
    sample_list_2.append(random())
print(sample_list_2)
# Out:
# [0.7122588726740138, 0.31590091373805784, 0.40299930040756426, 0.08675674261481825, 0.48098790303959027, 0.7078393537955463, 0.7305307563318612, 0.1525234590717084, 0.4938331573557275, 0.20861059253134806, 0.7615650179291346, 0.6589195827162925, 0.7159280551996693, 0.2737213165472918, 0.9998651973168933, 0.21374317228641793, 0.32389802127301426, 0.21791344261957069, 0.03582114464846575, 0.7326521699831451, 0.9508016874104916, 0.945142902638451, 0.759832087926214, 0.4860278394322103, 0.6144230859383168, 0.7430771529768334, 0.8946562304858433, 0.18818981182241157, 0.24561159310351377, 0.28603170836827896, 0.4006522720896385, 0.9734597459656227, 0.8913864279543042, 0.33470274163892255, 0.17907377153214776, 0.044908106992626595, 0.6748556775127044, 0.8444187630837022, 0.5103533400615148, 0.94828038489379, 0.6027384173570826, 0.5469348706989731, 0.8657103542396362, 0.18380077133329586, 0.3397213105641189, 0.19067236240639718, 0.712751909089711, 0.6632536463136707, 0.9222535689939185, 0.45
# ...

# %%
len(sample_list_2)
# Out:
# 80

# %%
set2=set(sample_list_2)

# %%
print(len(set2))
# Out:
# 80

# %%
list(set1.difference(set2))
# Out:
# [0.7235675066861962,
#  0.4520688792143841,
#  0.7632245341031687,
#  0.43109172379973604,
#  0.8957296595219961,
#  0.471678261351385,
#  0.47526165390596375,
#  0.8504013851262702,
#  0.6345681619147643,
#  0.8361210458306962,
#  0.05119174899621726,
#  0.351460117137542,
#  0.9571316758511517,
#  0.25316006007152614,
#  0.24357206967582146,
#  0.48077146126142667,
#  0.6360466578490152,
#  0.6167341761094327,
#  0.44264207886794515,
#  0.5025107563110689,
#  0.31872358231863385,
#  0.8149943150173597,
#  0.9860895889340866,
#  0.6089164137864687,
#  0.6928329208882981,
#  0.24726372575321254,
#  0.5555874558471873,
#  0.691699095279502,
#  0.7165658556894765,
#  0.05917837814358751,
#  0.030134570979092667,
#  0.7562526004511118,
#  0.32354059812282465,
#  0.14685699981790556,
#  0.10304121672068967,
#  0.09006541040829608,
#  0.5782529616480645,
#  0.024325494547958626,
#  0.026334382861903705,
#  0.8301799353905501,
#  0.8507434222731939,
#  0.44567810377570016,
# ...

# %%
len(list(set1.difference(set2)))
# Out:
# 80

# %%
len(list(set2.difference(set1)))
# Out:
# 80

# %%
if (set1 & set2):
    print(set1 & set2)
else:
    print("No Error find and No Commen elements Find")
# Out:
# No Error find and No Commen elements Find
