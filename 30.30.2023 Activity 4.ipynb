# %%
# Activity 4 (Thursday)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from warnings import filterwarnings
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv(r"C:/Users/DELL/Documents/GitHub/IH_DA_FT_MAR_2023/Class_Materials/Case_Studies/Data_Marketing_Customer_Analysis_Round3.csv")
df
# Out:
#             region  customer_lifetime_value response  coverage education  \
# 0          central                     4809       no     basic   college
# 1      west region                     2228       no     basic   college
# 2             east                    14947       no     basic  bachelor
# 3       north west                    22332      yes  extended   college
# 4       north west                     9025       no   premium  bachelor
# ...            ...                      ...      ...       ...       ...
# 10684      central                    15563       no   premium  bachelor
# 10685   north west                     5259       no     basic   college
# 10686      central                    23893       no  extended  bachelor
# 10687  west region                    11971       no   premium   college
# 10688      central                     6857       no     basic  bachelor
#
#       effective_to_date month employment_status gender  income  ...  \
# ...

# %%
# Show a plot of the total number of responses.++++++++++++++++++++++++++++
# Show a plot of the response by the sales channel.
# Show a plot of the response by the total claim amount.
# Show a plot of the response by income.
# (Optional) plot any interesting findings/insights(minimum three) that describe some interesting facts about your data set and its input variables as well as relationships with the target feature.
# Clean your notebook and make it readable and presentable with a good documentation that summarizes the Data Cleaning, Exploration(including plots) Steps that you have performed.
# Footer

# %%
df= df4.groupby(["response"], as_index=False).agg(count=("response", "count"))
df4
# df.plot(df.columns, figsize=(5, 3))
# plt.plot(df["response"],df["count"])
df.plot(x="response", y="count", kind="bar")
# Out:
# <AxesSubplot:xlabel='response'>

# %%
df
# Out:
#             region  customer_lifetime_value response  coverage education  \
# 0          central                     4809       no     basic   college
# 1      west region                     2228       no     basic   college
# 2             east                    14947       no     basic  bachelor
# 3       north west                    22332      yes  extended   college
# 4       north west                     9025       no   premium  bachelor
# ...            ...                      ...      ...       ...       ...
# 10684      central                    15563       no   premium  bachelor
# 10685   north west                     5259       no     basic   college
# 10686      central                    23893       no  extended  bachelor
# 10687  west region                    11971       no   premium   college
# 10688      central                     6857       no     basic  bachelor
#
#       effective_to_date month employment_status gender  income  ...  \
# ...

# %%
response = df['response'].value_counts()
response
# Out:
# no     9316
# yes    1373
# Name: response, dtype: int64

# %%
plt.bar(response.index,response,color=('yellow','blue')) 
plt.title('response by the Sales_channel', fontweight='bold') 
plt.xticks(ticks=[0,1],labels=["yes","no"])
plt.ylabel("sales_channel")
# Out:
# Text(0, 0.5, 'sales_channel')

# %%
plt.bar(response.index,response,color=('red','green')) 
plt.title('response by the total_claim_amount', fontweight='bold') 
plt.xticks(ticks=[0,1],labels=["yes","no"])
plt.ylabel("total_claim_amount")
# Out:
# Text(0, 0.5, 'total_claim_amount')

# %%
plt.bar(response.index,response,color=('black','blue')) 
plt.title('response by the Income', fontweight='bold') 
plt.xticks(ticks=[0,1],labels=["yes","no"])
plt.ylabel("Income")
# Out:
# Text(0, 0.5, 'Income')

# %%
response = df4['response'].value_counts()
response
response_by_channel = df.groupby(['response','sales_channel'])['response'].count().rename('count').reset_index()

# %%
response_by_channel
# Out:
#   response sales_channel  count
# 0       no         agent   3340
# 1       no        branch   2665
# 2       no   call center   1890
# 3       no           web   1421
# 4      yes         agent    679
# 5      yes        branch    310
# 6      yes   call center    209
# 7      yes           web    175

# %%
sns.barplot(x = 'sales_channel',y = 'count', hue = 'response', data= response_by_channel)
# Out:
# <AxesSubplot:xlabel='sales_channel', ylabel='count'>

# %%
df= df.groupby(["response","sales_channel"], as_index=False).agg(count=("response", "count"))
df
df.groupby("sales_channel"),["count"].df.plot(x="response", y="count", kind="bar")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3020\737255318.py in <module>
#       1 df= df.groupby(["response","sales_channel"], as_index=False).agg(count=("response", "count"))
#       2 df
# ----> 3 df.groupby("sales_channel"),["count"].df.plot(x="response", y="count", kind="bar")
#
# AttributeError: 'list' object has no attribute 'df'
