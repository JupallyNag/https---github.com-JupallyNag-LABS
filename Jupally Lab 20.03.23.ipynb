# %% [markdown]
#    Hello Team, My Name is Jupally Nagarjuna , I'm origin from India. I would like to visit Paris to see Eiffel Tower and Mona lesa portrait and Loure Museum

# %%
Name = input ( "Enter your Name" )
# Out:
# Enter your Name Jupally Nagarjuna

# %%
My_Name ="Jupally Nagarjuna:"

# %%
My_Name
# Out:
# 'Jupally Nagarjuna:'

# %% [markdown]
# ![IMG20221207100909.jpg](attachment:IMG20221207100909.jpg)

# %% [markdown]
# - Eiffle Tower

# %% [markdown]
# ![Eiffel%20Tower.jpg](attachment:Eiffel%20Tower.jpg)

# %% [markdown]
# - Mona Lisa Portrait

# %% [markdown]
# ![Mona%20Lisa.jpg](attachment:Mona%20Lisa.jpg)

# %% [markdown]
# - Loure Museum

# %% [markdown]
# ![Museu%20do%20Louvre.jpg](attachment:Museu%20do%20Louvre.jpg)
