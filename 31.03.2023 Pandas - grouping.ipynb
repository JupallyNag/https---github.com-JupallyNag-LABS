# %%
import pandas as pd
cars = pd.read_csv(r"C:/Users/DELL/Documents/GitHub/IH_DA_FT_MAR_2023/Class_Materials/Pandas/Labs/vehicles.csv")
# print(cars)

# %%
cars.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0          4  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1          6  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2          4  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3          6  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4          6  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %%
#print(cars["Model"].count())
print(cars["Model"].nunique())
# Out:
# 3608

# %%
df1= cars.groupby("Make").count()
display(df1.columns)
# Out:
# Index(['Model', 'Year', 'Engine Displacement', 'Cylinders', 'Transmission',
#        'Drivetrain', 'Vehicle Class', 'Fuel Type', 'Fuel Barrels/Year',
#        'City MPG', 'Highway MPG', 'Combined MPG', 'CO2 Emission Grams/Mile',
#        'Fuel Cost/Year'],
#       dtype='object')

# %%
sdf=cars.groupby(['Make'], as_index=False).count()
df2 = pd.DataFrame(sdf)
display(df2)
# Out:
#                             Make  Model  Year  Engine Displacement  Cylinders  \
# 0                     AM General      4     4                    4          4
# 1               ASC Incorporated      1     1                    1          1
# 2                          Acura    302   302                  302        302
# 3                     Alfa Romeo     41    41                   41         41
# 4    American Motors Corporation     22    22                   22         22
# ..                           ...    ...   ...                  ...        ...
# 122                   Volkswagen   1047  1047                 1047       1047
# 123                        Volvo    717   717                  717        717
# 124        Wallace Environmental     32    32                   32         32
# 125                         Yugo      8     8                    8          8
# 126                        smart     20    20                   20         20
#
# ...

# %%
df3= df2.query('Model==Model.max()')
display(df3.columns)
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Displacement', 'Cylinders',
#        'Transmission', 'Drivetrain', 'Vehicle Class', 'Fuel Type',
#        'Fuel Barrels/Year', 'City MPG', 'Highway MPG', 'Combined MPG',
#        'CO2 Emission Grams/Mile', 'Fuel Cost/Year'],
#       dtype='object')

# %%
df4= cars.groupby(['Make'], as_index=False)['CO2 Emission Grams/Mile'].mean()
display(df4)
# Out:
#                             Make  CO2 Emission Grams/Mile
# 0                     AM General               611.358244
# 1               ASC Incorporated               555.437500
# 2                          Acura               422.585325
# 3                     Alfa Romeo               463.952115
# 4    American Motors Corporation               505.758823
# ..                           ...                      ...
# 122                   Volkswagen               392.741721
# 123                        Volvo               435.803755
# 124        Wallace Environmental               657.990029
# 125                         Yugo               356.068256
# 126                        smart               247.030556
#
# [127 rows x 2 columns]

# %%
df5= df4.sort_values('CO2 Emission Grams/Mile')
display(df5)
# Out:
#                                    Make  CO2 Emission Grams/Mile
# 36                               Fisker               169.000000
# 126                               smart               247.030556
# 35                                 Fiat               304.666560
# 26                             Daihatsu               310.188060
# 67                                 MINI               313.716862
# ..                                  ...                      ...
# 58               Laforza Automobile Inc               807.909091
# 15                              Bugatti               873.062500
# 112    Superior Coaches Div E.p. Dutton               888.700000
# 101  S and S Coach Company  E.p. Dutton               888.700000
# 119                              Vector              1049.159722
#
# [127 rows x 2 columns]

# %%
cars['Year'].describe()
# Out:
# count    35952.00000
# mean      2000.71640
# std         10.08529
# min       1984.00000
# 25%       1991.00000
# 50%       2001.00000
# 75%       2010.00000
# max       2017.00000
# Name: Year, dtype: float64

# %% [markdown]
# #(Optional)
# #Use pd.cut or pd.qcut to create 4 groups (bins) of cars, by Year.
# #We want to explore how cars have evolved decade by decade.

# %%
cars['Year'].unique()
# Out:
# array([1984, 1985, 1987, 1997, 1998, 1999, 1995, 1996, 2001, 2002, 2003,
#        2000, 2004, 2013, 2014, 2015, 2016, 2017, 1986, 1988, 1989, 1990,
#        1991, 1992, 1993, 1994, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012], dtype=int64)

# %%
cars.sort_values(by=['Year'], inplace=True)

# %%
cars['Year'].unique()
# Out:
# array([1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994,
#        1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005,
#        2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016,
#        2017], dtype=int64)

# %%
(2017-1984)/4
# Out:
# 8.25

# %%
cars.groupby(['Year']).filter(lambda x: x["Year"].mean().sort_values(by="Year"))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5104\2040406450.py in <module>
# ----> 1 cars.groupby(['Year']).filter(lambda x: x["Year"].mean().sort_values(by="Year"))
#       2
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in filter(self, func, dropna, *args, **kwargs)
#    1302             object.__setattr__(group, "name", name)
#    1303
# -> 1304             res = func(group, *args, **kwargs)
#    1305
#    1306             try:
#
# ~\AppData\Local\Temp\ipykernel_5104\2040406450.py in <lambda>(x)
# ----> 1 cars.groupby(['Year']).filter(lambda x: x["Year"].mean().sort_values(by="Year"))
#       2
#
# AttributeError: 'float' object has no attribute 'sort_values'

# %%
import pandas as pd
import numpy as np
cars = pd.cut(np.array ('bins'[0,4,8,10], 4))
# Out:
# <>:3: SyntaxWarning: str indices must be integers or slices, not tuple; perhaps you missed a comma?
# <>:3: SyntaxWarning: str indices must be integers or slices, not tuple; perhaps you missed a comma?
# C:\Users\DELL\AppData\Local\Temp\ipykernel_5104\835517264.py:3: SyntaxWarning: str indices must be integers or slices, not tuple; perhaps you missed a comma?
#   cars = pd.cut(np.array ('bins'[0,4,8,10], 4))
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5104\835517264.py in <module>
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 cars = pd.cut(np.array ('bins'[0,4,8,10], 4))
#
# TypeError: string indices must be integers

# %%
df5 = pd.cut('Year',['Year'].labels=False, retbins=True,
       right=False, duplicates='drop')
# Out:
#   File "C:\Users\DELL\AppData\Local\Temp\ipykernel_5104\2165442869.py", line 1
#     df5 = pd.cut('Year',['Year'].labels=False, retbins=True,
#                         ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %%
bins = [0, 4, 6, 10]
Years = ["1985","2005","2015","2017"]
df5['Years'] = pd.cut(df5['Years'], bins=bins, labels=labels)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Years'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
#Did cars consume more gas in the eighties?
#show the average City_Km/Liter by year_range

# %%
#Which brands are more environment friendly?#

# %%
df= cars.groupby(['Year'], as_index=False).loc['Year'].mean()
display(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5104\793681763.py in <module>
# ----> 1 df= cars.groupby(['Year'], as_index=False).loc['Year'].mean()
#       2 display(df)
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     902             return self[attr]
#     903
# --> 904         raise AttributeError(
#     905             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     906         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'loc'

# %%
cars.groupby('Year').agg(['max',"min"])
# Out:
#                        Make                               Model  \
#                         max               min               max
# Year
# 1984             Volkswagen        AM General         Wagon 4WD
# 1985                  Volvo        AM General             XT-DL
# 1986                   Yugo             Acura             XT-DL
# 1987                   Yugo  ASC Incorporated             XT-DL
# 1988                   Yugo             Acura             XT-DL
# 1989                   Yugo             Acura             XT-DL
# 1990                   Yugo             Acura            XT 4WD
# 1991  Wallace Environmental             Acura            XT 4WD
# 1992  Wallace Environmental             Acura    Yukon 1500 4WD
# 1993                  Volvo             Acura    Yukon 1500 4WD
# 1994                  Volvo             Acura   Yukon K1500 4WD
# 1995                  Volvo             Acura    Yukon 1500 4WD
# 1996                  Volvo             Acura       Z3 Roadster
# ...
